# %%
import random

POPULATION_SIZE = 100

GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

TARGET = "I love GeeksforGeeks"


class Individual(object):
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(self):
        gene = random.choice(GENES)
        return gene

    @classmethod
    def create_gnome(self):
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt:
                fitness += 1
        return fitness


def main():
    global POPULATION_SIZE
    generation = 1
    found = False
    population = []
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:
        population = sorted(population, key=lambda x: x.fitness)
        if population[0].fitness <= 0:
            found = True
            break
        new_generation = []
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".format(
            generation,
            "".join(population[0].chromosome),
            population[0].fitness
        ))

        generation += 1

    print("Generation: {}\tString: {}\tFitness: {}".format(
        generation,
        "".join(population[0].chromosome),
        population[0].fitness
    ))


if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: OiTP3SOZ#zLsbf;7eUR{	Fitness: 18
# Generation: 2	String: OiTP3SOZ#zLsbf;7eUR{	Fitness: 18
# Generation: 3	String: #vlm}J @Se@V8!ISmAn@	Fitness: 17
# Generation: 4	String: j j%{Y @5jPqf.STdAk:	Fitness: 16
# Generation: 5	String: !=vP}, G}!JsbkrDerR@	Fitness: 15
# Generation: 6	String: 6AlsQK GEe@sf!IStk0@	Fitness: 14
# Generation: 7	String: # l24T GFe slfr.LRnM	Fitness: 13
# Generation: 8	String: # l24T GFe slfr.LRnM	Fitness: 13
# Generation: 9	String: !fl5KY 2#e(sHUr7eekp	Fitness: 12
# Generation: 10	String: !fl5KY 2#e(sHUr7eekp	Fitness: 12
# Generation: 11	String: !flS4Y G#josfUrYeekp	Fitness: 11
# Generation: 12	String: !flS4Y G#josfUrYeekp	Fitness: 11
# Generation: 13	String: t lo}X G#eNsf!r7eekM	Fitness: 8
# Generation: 14	String: t lo}X G#eNsf!r7eekM	Fitness: 8
# Generation: 15	String: t lo}X G#eNsf!r7eekM	Fitness: 8
# Generation: 16	String: t lo}X G#eNsf!r7eekM	Fitness: 8
# Generation: 17	String: t lo}X G#eNsf!r7eekM	Fitness: 8
# Generation: 18	String: 6 lovX G#eksf!(.eek9	Fitness: 7
# Generation: 19	String: 6 lovX G#eksf!(.eek9	Fitness: 7
# Generation: 20	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 21	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 22	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 23	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 24	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 25	String: u lovs Gee}sfUrheekp	Fitness: 6
# Generation: 26	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 27	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 28	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 29	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 30	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 31	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 32	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 33	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 34	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 35	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 36	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 37	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 38	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 39	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 40	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 41	String: i lovs GeeksfRrteek9	Fitness: 5
# Generation: 42	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 43	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 44	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 45	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 46	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 47	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 48	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 49	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 50	String: 9 lov6 Geeksforheek9	Fitness: 4
# Generation: 51	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 52	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 53	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 54	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 55	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 56	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 57	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 58	String: 9 love Geeksfor5eekZ	Fitness: 3
# Generation: 59	String: N love GeeksforGeekS	Fitness: 2
# Generation: 60	String: N love GeeksforGeekS	Fitness: 2
# Generation: 61	String: N love GeeksforGeekS	Fitness: 2
# Generation: 62	String: N love GeeksforGeekS	Fitness: 2
# Generation: 63	String: N love GeeksforGeekS	Fitness: 2
# Generation: 64	String: N love GeeksforGeekS	Fitness: 2
# Generation: 65	String: N love GeeksforGeekS	Fitness: 2
# Generation: 66	String: N love GeeksforGeekS	Fitness: 2
# Generation: 67	String: N love GeeksforGeekS	Fitness: 2
# Generation: 68	String: N love GeeksforGeekS	Fitness: 2
# Generation: 69	String: N love GeeksforGeekS	Fitness: 2
# Generation: 70	String: N love GeeksforGeekS	Fitness: 2
# Generation: 71	String: N love GeeksforGeekS	Fitness: 2
# Generation: 72	String: N love GeeksforGeekS	Fitness: 2
# Generation: 73	String: N love GeeksforGeekS	Fitness: 2
# Generation: 74	String: N love GeeksforGeekS	Fitness: 2
# Generation: 75	String: N love GeeksforGeekS	Fitness: 2
# Generation: 76	String: N love GeeksforGeekS	Fitness: 2
# Generation: 77	String: N love GeeksforGeekS	Fitness: 2
# Generation: 78	String: N love GeeksforGeekS	Fitness: 2
# Generation: 79	String: N love GeeksforGeekS	Fitness: 2
# Generation: 80	String: N love GeeksforGeekS	Fitness: 2
# Generation: 81	String: N love GeeksforGeekS	Fitness: 2
# Generation: 82	String: N love GeeksforGeekS	Fitness: 2
# Generation: 83	String: N love GeeksforGeekS	Fitness: 2
# Generation: 84	String: N love GeeksforGeekS	Fitness: 2
# Generation: 85	String: N love GeeksforGeekS	Fitness: 2
# Generation: 86	String: N love GeeksforGeekS	Fitness: 2
# Generation: 87	String: N love GeeksforGeekS	Fitness: 2
# Generation: 88	String: N love GeeksforGeekS	Fitness: 2
# Generation: 89	String: N love GeeksforGeekS	Fitness: 2
# Generation: 90	String: N love GeeksforGeekS	Fitness: 2
# Generation: 91	String: N love GeeksforGeekS	Fitness: 2
# Generation: 92	String: N love GeeksforGeekS	Fitness: 2
# Generation: 93	String: N love GeeksforGeekS	Fitness: 2
# Generation: 94	String: N love GeeksforGeekS	Fitness: 2
# Generation: 95	String: N love GeeksforGeekS	Fitness: 2
# Generation: 96	String: N love GeeksforGeekS	Fitness: 2
# Generation: 97	String: N love GeeksforGeekS	Fitness: 2
# Generation: 98	String: N love GeeksforGeekS	Fitness: 2
# Generation: 99	String: N love GeeksforGeekS	Fitness: 2
# Generation: 100	String: N love GeeksforGeekS	Fitness: 2
# Generation: 101	String: N love GeeksforGeekS	Fitness: 2
# Generation: 102	String: N love GeeksforGeekS	Fitness: 2
# Generation: 103	String: N love GeeksforGeekS	Fitness: 2
# Generation: 104	String: N love GeeksforGeekS	Fitness: 2
# Generation: 105	String: N love GeeksforGeekS	Fitness: 2
# Generation: 106	String: N love GeeksforGeekS	Fitness: 2
# Generation: 107	String: N love GeeksforGeekS	Fitness: 2
# Generation: 108	String: N love GeeksforGeekS	Fitness: 2
# Generation: 109	String: N love GeeksforGeekS	Fitness: 2
# Generation: 110	String: N love GeeksforGeekS	Fitness: 2
# Generation: 111	String: N love GeeksforGeekS	Fitness: 2
# Generation: 112	String: N love GeeksforGeekS	Fitness: 2
# Generation: 113	String: N love GeeksforGeekS	Fitness: 2
# Generation: 114	String: N love GeeksforGeekS	Fitness: 2
# Generation: 115	String: N love GeeksforGeekS	Fitness: 2
# Generation: 116	String: N love GeeksforGeekS	Fitness: 2
# Generation: 117	String: N love GeeksforGeekS	Fitness: 2
# Generation: 118	String: N love GeeksforGeekS	Fitness: 2
# Generation: 119	String: N love GeeksforGeekS	Fitness: 2
# Generation: 120	String: N love GeeksforGeekS	Fitness: 2
# Generation: 121	String: N love GeeksforGeekS	Fitness: 2
# Generation: 122	String: N love GeeksforGeekS	Fitness: 2
# Generation: 123	String: N love GeeksforGeekS	Fitness: 2
# Generation: 124	String: I love GeeksforGeekS	Fitness: 1
# Generation: 125	String: I love GeeksforGeekS	Fitness: 1
# Generation: 126	String: I love GeeksforGeekS	Fitness: 1
# Generation: 127	String: I love GeeksforGeekS	Fitness: 1
# Generation: 128	String: I love GeeksforGeekS	Fitness: 1
# Generation: 129	String: I love GeeksforGeekS	Fitness: 1
# Generation: 130	String: I love GeeksforGeekS	Fitness: 1
# Generation: 131	String: I love GeeksforGeekS	Fitness: 1
# Generation: 132	String: I love GeeksforGeekS	Fitness: 1
# Generation: 133	String: I love GeeksforGeekS	Fitness: 1
# Generation: 134	String: I love GeeksforGeekS	Fitness: 1
# Generation: 135	String: I love GeeksforGeekS	Fitness: 1
# Generation: 136	String: I love GeeksforGeekS	Fitness: 1
# Generation: 137	String: I love GeeksforGeekS	Fitness: 1
# Generation: 138	String: I love GeeksforGeekS	Fitness: 1
# Generation: 139	String: I love GeeksforGeekS	Fitness: 1
# Generation: 140	String: I love GeeksforGeekS	Fitness: 1
# Generation: 141	String: I love GeeksforGeekS	Fitness: 1
# Generation: 142	String: I love GeeksforGeekS	Fitness: 1
# Generation: 143	String: I love GeeksforGeekS	Fitness: 1
# Generation: 144	String: I love GeeksforGeekS	Fitness: 1
# Generation: 145	String: I love GeeksforGeekS	Fitness: 1
# Generation: 146	String: I love GeeksforGeekS	Fitness: 1
# Generation: 147	String: I love GeeksforGeekS	Fitness: 1
# Generation: 148	String: I love GeeksforGeekS	Fitness: 1
# Generation: 149	String: I love GeeksforGeekS	Fitness: 1
# Generation: 150	String: I love GeeksforGeekS	Fitness: 1
# Generation: 151	String: I love GeeksforGeeks	Fitness: 0
